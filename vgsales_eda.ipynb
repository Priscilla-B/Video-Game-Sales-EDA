# %% [markdown]
# # EXPLORATORY DATA  ANALYSIS - VIDEO GAME SALES

# %% [markdown]
# # UNDERSTANDING THE DATASET

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#EXPLORATORY-DATA--ANALYSIS---VIDEO-GAME-SALES" data-toc-modified-id="EXPLORATORY-DATA--ANALYSIS---VIDEO-GAME-SALES-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>EXPLORATORY DATA  ANALYSIS - VIDEO GAME SALES</a></span></li><li><span><a href="#UNDERSTANDING-THE-DATASET" data-toc-modified-id="UNDERSTANDING-THE-DATASET-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>UNDERSTANDING THE DATASET</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Importing-modules-and-dataset-to-inspect,-clean-and-further-process-for-analysis." data-toc-modified-id="Importing-modules-and-dataset-to-inspect,-clean-and-further-process-for-analysis.-2.0.1"><span class="toc-item-num">2.0.1&nbsp;&nbsp;</span>Importing modules and dataset to inspect, clean and further process for analysis.</a></span></li><li><span><a href="#Basic-Description-of-Data" data-toc-modified-id="Basic-Description-of-Data-2.0.2"><span class="toc-item-num">2.0.2&nbsp;&nbsp;</span>Basic Description of Data</a></span></li><li><span><a href="#Dealing-with-missing-values" data-toc-modified-id="Dealing-with-missing-values-2.0.3"><span class="toc-item-num">2.0.3&nbsp;&nbsp;</span>Dealing with missing values</a></span><ul class="toc-item"><li><span><a href="#Checking-for-outliers-in-the-dataset-using-the-describe()-function-below,-which-provides-a-statistical---summary-of-all-the-quantitative-variables." data-toc-modified-id="Checking-for-outliers-in-the-dataset-using-the-describe()-function-below,-which-provides-a-statistical---summary-of-all-the-quantitative-variables.-2.0.3.1"><span class="toc-item-num">2.0.3.1&nbsp;&nbsp;</span>Checking for outliers in the dataset using the describe() function below, which provides a statistical   summary of all the quantitative variables.</a></span></li><li><span><a href="#The-years-2017-and-2020-have-(3)-and-(1)-counts-respectively,-are-outliers-dectected." data-toc-modified-id="The-years-2017-and-2020-have-(3)-and-(1)-counts-respectively,-are-outliers-dectected.-2.0.3.2"><span class="toc-item-num">2.0.3.2&nbsp;&nbsp;</span>The years 2017 and 2020 have (3) and (1) counts respectively, are outliers dectected.</a></span></li><li><span><a href="#The-boxplot-,-histogram-and-scatter-diagrams-below-gives-a-clear-indication-of-the-outliers." data-toc-modified-id="The-boxplot-,-histogram-and-scatter-diagrams-below-gives-a-clear-indication-of-the-outliers.-2.0.3.3"><span class="toc-item-num">2.0.3.3&nbsp;&nbsp;</span>The boxplot , histogram and scatter diagrams below gives a clear indication of the outliers.</a></span></li><li><span><a href="#Using-the-trimming-method-to-deal-with-the-outliers,-by-first-creating-an-index-for-all-the-data-points-where-the-year-takes-2017-and-2020--values." data-toc-modified-id="Using-the-trimming-method-to-deal-with-the-outliers,-by-first-creating-an-index-for-all-the-data-points-where-the-year-takes-2017-and-2020--values.-2.0.3.4"><span class="toc-item-num">2.0.3.4&nbsp;&nbsp;</span>Using the trimming method to deal with the outliers, by first creating an index for all the data points where the year takes 2017 and 2020  values.</a></span></li><li><span><a href="#Then-the-index-rows-are--dropped-from-the-data,-while-displaying-the--summary-of-the-statistics-for-the-variables." data-toc-modified-id="Then-the-index-rows-are--dropped-from-the-data,-while-displaying-the--summary-of-the-statistics-for-the-variables.-2.0.3.5"><span class="toc-item-num">2.0.3.5&nbsp;&nbsp;</span>Then the index rows are  dropped from the data, while displaying the  summary of the statistics for the variables.</a></span></li></ul></li><li><span><a href="#Checking-for-the-relationship-between-the-variables---helping-to-detect-outliers" data-toc-modified-id="Checking-for-the-relationship-between-the-variables---helping-to-detect-outliers-2.0.4"><span class="toc-item-num">2.0.4&nbsp;&nbsp;</span>Checking for the relationship between the variables - helping to detect outliers</a></span></li><li><span><a href="#Heatmap-showing-correlation-between-variables" data-toc-modified-id="Heatmap-showing-correlation-between-variables-2.0.5"><span class="toc-item-num">2.0.5&nbsp;&nbsp;</span>Heatmap showing correlation between variables</a></span><ul class="toc-item"><li><span><a href="#Observations:" data-toc-modified-id="Observations:-2.0.5.1"><span class="toc-item-num">2.0.5.1&nbsp;&nbsp;</span>Observations:</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Questions" data-toc-modified-id="Questions-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Questions</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.-Trend-of-global-video-game-sales-over-the-years." data-toc-modified-id="1.-Trend-of-global-video-game-sales-over-the-years.-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>1. Trend of global video game sales over the years.</a></span></li><li><span><a href="#2.-Years-that-had-the-highest-and-lowest-game-sales." data-toc-modified-id="2.-Years-that-had-the-highest-and-lowest-game-sales.-3.0.2"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>2. Years that had the highest and lowest game sales.</a></span></li><li><span><a href="#3.-What-is-the-trend-of-Video-game-sales-by-regions-over-the-years?" data-toc-modified-id="3.-What-is-the-trend-of-Video-game-sales-by-regions-over-the-years?-3.0.3"><span class="toc-item-num">3.0.3&nbsp;&nbsp;</span>3. What is the trend of Video game sales by regions over the years?</a></span></li><li><span><a href="#4.-Which-regions-have-the-highest-share-of-global-video-game-sales?" data-toc-modified-id="4.-Which-regions-have-the-highest-share-of-global-video-game-sales?-3.0.4"><span class="toc-item-num">3.0.4&nbsp;&nbsp;</span>4. Which regions have the highest share of global video game sales?</a></span></li><li><span><a href="#5.-What-is-the-trend-of-Video-game-sales-by-platfroms-over-the-years?" data-toc-modified-id="5.-What-is-the-trend-of-Video-game-sales-by-platfroms-over-the-years?-3.0.5"><span class="toc-item-num">3.0.5&nbsp;&nbsp;</span>5. What is the trend of Video game sales by platfroms over the years?</a></span></li><li><span><a href="#6.-Which-platforms-have-the-highest--share-of-global-video-game-sales?" data-toc-modified-id="6.-Which-platforms-have-the-highest--share-of-global-video-game-sales?-3.0.6"><span class="toc-item-num">3.0.6&nbsp;&nbsp;</span>6. Which platforms have the highest  share of global video game sales?</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ###  Importing modules and dataset to inspect, clean and further process for analysis.

# %%
import pandas as pd 
from pandas import DataFrame
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
import scipy
# %matplotlib inline

# %%
# Importing the dataset
# We promoted the rank column as the index column
vgs = pd.read_csv('vgsales.csv', index_col='Rank')
vgs
# Out:
#                                                    Name Platform    Year  \
# Rank
# 1                                            Wii Sports      Wii  2006.0
# 2                                     Super Mario Bros.      NES  1985.0
# 3                                        Mario Kart Wii      Wii  2008.0
# 4                                     Wii Sports Resort      Wii  2009.0
# 5                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                        Know How 2       DS  2010.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# ...

# %% [markdown]
# Our dataset consists of 16598 rows and 10 columns.
# The Columns are:
# * Name: for the name of the video games
# * Platform: for the platforms the video games are hosted on
# * Genre: for the kind of video game
# * Publisher: for the video game publisher
# * NA_Sales: Sales made in North America, in millions of units
# * JP_Sales: Sales made in Japan, in millions of units
# * EU_Sales: Sales made in Europe, in millions of units
# * Other_Sales: Sales made in other regions, in millions of units
# * Global_Sales: Total sales made worldwide, in millions of units

# %%
# getting basic information about data
vgs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16598 entries, 1 to 16600
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16598 non-null  object
#  1   Platform      16598 non-null  object
#  2   Year          16327 non-null  float64
#  3   Genre         16598 non-null  object
#  4   Publisher     16540 non-null  object
#  5   NA_Sales      16598 non-null  float64
#  6   EU_Sales      16598 non-null  float64
#  7   JP_Sales      16598 non-null  float64
#  8   Other_Sales   16598 non-null  float64
#  9   Global_Sales  16598 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# The information displayed above shows the year and publisher columns have fewer non-null values compared to the other columns.
# Hence they have some missing values.
#  Also, it shows the year column values have been translated as floats instead of integers.

# %% [markdown]
# ### Basic Description of Data
# * The aim of this stage is to help us get a feel of the data and give us an idea of the data distribution, challenges with the data and how to effectively deal with those challenges to improve our analysis

# %%
# getting a summary statistics of the dataset
vgs.describe()
# Out:
#                Year      NA_Sales      EU_Sales      JP_Sales   Other_Sales  \
# count  16327.000000  16598.000000  16598.000000  16598.000000  16598.000000
# mean    2006.406443      0.264667      0.146652      0.077782      0.048063
# std        5.828981      0.816683      0.505351      0.309291      0.188588
# min     1980.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2003.000000      0.000000      0.000000      0.000000      0.000000
# 50%     2007.000000      0.080000      0.020000      0.000000      0.010000
# 75%     2010.000000      0.240000      0.110000      0.040000      0.040000
# max     2020.000000     41.490000     29.020000     10.220000     10.570000
#
#        Global_Sales
# count  16598.000000
# mean       0.537441
# std        1.555028
# min        0.010000
# 25%        0.060000
# 50%        0.170000
# 75%        0.470000
# max       82.740000

# %% [markdown]
# These are some interesting things we have noted about the summary statistics on the dataset:
#
# * The mean year is 2006 which shows that the data is centered around 2006
# * The most current year is 2020 and the oldest year is 1980
# * This shows the data was collected for the period 1980-2020(a 40-year period)
# * The global sales value is within a range of 100,000 to 82,740,000
# * The average global sales over the years is 537, 441, which is more skewed towards the left

# %%
# showing the first ten rows
vgs.head(10)
# Out:
#                            Name Platform    Year         Genre Publisher  \
# Rank
# 1                    Wii Sports      Wii  2006.0        Sports  Nintendo
# 2             Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 3                Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 4             Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 5      Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 6                        Tetris       GB  1989.0        Puzzle  Nintendo
# 7         New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 8                      Wii Play      Wii  2006.0          Misc  Nintendo
# 9     New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 10                    Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Rank
# 1        41.49     29.02      3.77         8.46         82.74
# ...

# %% [markdown]
# The first ten rows of the dataset shows top ten video games in terms of global sales.
# In the first 10 rows, there are no missing values, or apparent errors.

# %%
# showing the bottom ten rows
vgs.tail(10)
# Out:
#                                                     Name Platform    Year  \
# Rank
# 16591                                   Mega Brain Boost       DS  2008.0
# 16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV  2016.0
# 16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP  2007.0
# 16594                                Myst IV: Revelation       PC  2004.0
# 16595                                           Plushees       DS  2008.0
# 16596                 Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                      Men in Black II: Alien Escape       GC  2003.0
# 16598   SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                         Know How 2       DS  2010.0
# 16600                                   Spirits & Spells      GBA  2003.0
#
#               Genre              Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Rank
# ...

# %% [markdown]
# The bottom ten rows of the dataset shows top ten video games in terms of global sales.
# In the bottom 10 rows, there are no missing values, or apparent errors.

# %%
# taking 20 random samples of the data
vgs.sample(20)
# Out:
#                                                     Name Platform    Year  \
# Rank
# 7778                                         Dream Salon       DS  2009.0
# 15513                              Uru: Ages Beyond Myst       PC  2003.0
# 11894                         Tom Clancy's Ghost Recon 2       GC  2005.0
# 10559                                        Dark Summit       XB  2001.0
# 14985                                  Rapala for Kinect     X360  2011.0
# 11460                            The Legend of Alon D'ar      PS2  2001.0
# 4993          Fragile Dreams: Farewell Ruins of the Moon      Wii  2009.0
# 9473                              Hasbro Family Fun Pack     XOne  2015.0
# 6380               Final Fantasy XI: Ultimate Collection     X360  2009.0
# 11026                          Hello Kitty's Cube Frenzy       PS  1998.0
# 9678                                       Sleeping Dogs       PC  2012.0
# 7498                  Battle of Giants: Dinosaurs Strike      Wii  2010.0
# ...

# %% [markdown]
# ### Dealing with missing values

# %%
# counting the number of missing values in each column
# this clearly shows that the year column has 271 missing values and the publisher column has 58
# since year is a fundamental part of our analysis, we will not drop those missi
vgs.isnull().sum()
# Out:
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
# extracting the records with the missing year values
null_bool = pd.isnull(vgs['Year'])
vgs[null_bool]
# Out:
#                               Name Platform  Year         Genre  \
# Rank
# 180                Madden NFL 2004      PS2   NaN        Sports
# 378               FIFA Soccer 2004      PS2   NaN        Sports
# 432     LEGO Batman: The Videogame      Wii   NaN        Action
# 471     wwe Smackdown vs. Raw 2006      PS2   NaN      Fighting
# 608                 Space Invaders     2600   NaN       Shooter
# ...                            ...      ...   ...           ...
# 16310                Freaky Flyers       GC   NaN        Racing
# 16330                    Inversion       PC   NaN       Shooter
# 16369  Hakuouki: Shinsengumi Kitan      PS3   NaN     Adventure
# 16430                 Virtua Quest       GC   NaN  Role-Playing
# 16496                   The Smurfs      3DS   NaN        Action
#
#                                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Rank
# 180                           Electronic Arts      4.26      0.26      0.01
# ...

# %%
# filling in the null values using the interpolation method
# the interpolation method is a more logical way of filling in the missing values 
# a linear interpolation is performed on the missing data points to guess which values are likely to be filled in
vgs_1 = vgs.interpolate(method='linear', limit_direction='forward', columns='Year')
vgs_1
# Out:
#                                                    Name Platform    Year  \
# Rank
# 1                                            Wii Sports      Wii  2006.0
# 2                                     Super Mario Bros.      NES  1985.0
# 3                                        Mario Kart Wii      Wii  2008.0
# 4                                     Wii Sports Resort      Wii  2009.0
# 5                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                        Know How 2       DS  2010.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# ...

# %%
# checking if there are still null values present
null_bool = pd.isnull(vgs_1['Year'])
vgs_1[null_bool]
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %%
# this is just to test a single record, which previously had a missing year value 
# it's clear that the null value has been filled in 
vgs_1.iloc[179, :]
# Out:
# Name            Madden NFL 2004
# Platform                    PS2
# Year                     2000.5
# Genre                    Sports
# Publisher       Electronic Arts
# NA_Sales                   4.26
# EU_Sales                   0.26
# JP_Sales                   0.01
# Other_Sales                0.71
# Global_Sales               5.23
# Name: 180, dtype: object

# %%
# since the year values have been presented as floating point numbers, we have to convert them to integers
vgs_1 = vgs_1.astype({'Year': 'int64'})
vgs_1
# Out:
#                                                    Name Platform  Year  \
# Rank
# 1                                            Wii Sports      Wii  2006
# 2                                     Super Mario Bros.      NES  1985
# 3                                        Mario Kart Wii      Wii  2008
# 4                                     Wii Sports Resort      Wii  2009
# 5                              Pokemon Red/Pokemon Blue       GB  1996
# ...                                                 ...      ...   ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16597                     Men in Black II: Alien Escape       GC  2003
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16599                                        Know How 2       DS  2010
# 16600                                  Spirits & Spells      GBA  2003
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# ...

# %%
# confirming if the year value has been accurately converted to an integer
vgs_1.iloc[179, :]
# Out:
# Name            Madden NFL 2004
# Platform                    PS2
# Year                       2000
# Genre                    Sports
# Publisher       Electronic Arts
# NA_Sales                   4.26
# EU_Sales                   0.26
# JP_Sales                   0.01
# Other_Sales                0.71
# Global_Sales               5.23
# Name: 180, dtype: object

# %%
# checking for missing values in publishers column
null_bool = pd.isnull(vgs_1['Publisher'])
vgs_1[null_bool].head(5)
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %%
# filling null values using forward fill
vgs_1 = vgs_1.fillna(method='ffill')
vgs_1
# Out:
#                                                    Name Platform  Year  \
# Rank
# 1                                            Wii Sports      Wii  2006
# 2                                     Super Mario Bros.      NES  1985
# 3                                        Mario Kart Wii      Wii  2008
# 4                                     Wii Sports Resort      Wii  2009
# 5                              Pokemon Red/Pokemon Blue       GB  1996
# ...                                                 ...      ...   ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16597                     Men in Black II: Alien Escape       GC  2003
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16599                                        Know How 2       DS  2010
# 16600                                  Spirits & Spells      GBA  2003
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# ...

# %%
# checking if null values have been filled
null_bool = pd.isnull(vgs_1['Publisher'])
vgs_1[null_bool]
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %% [markdown]
# #### Checking for Outliers in the Data Set

# %% [markdown]
# * we are only focusing on the year column because the outliers in the other columns such as global sales are not
# * so extreme and are also not due to errors.
# * They are a mere indication of high level of sales

# %%
# Year value count showing the outliers
# 2020 and 2017 have 1 and 3 value counts respectively
# including them will hamper our analysis
vgs_outliers = vgs_1.Year.value_counts()
vgs_outliers[vgs_outliers<50]
# Out:
# 1981    46
# 1992    45
# 1991    41
# 1982    36
# 1986    21
# 1983    17
# 1989    17
# 1987    16
# 1990    16
# 1988    15
# 1984    14
# 1985    14
# 1980     9
# Name: Year, dtype: int64

# %%
# visualizing the distribution of data for the year values
# using a histogram
vgs['Year'].plot(kind='hist', bins=40, figsize=(12,6),edgecolor='black')
plt.title("Count of Values by Year")
# Out:
# Text(0.5, 1.0, 'Count of Values by Year')

# %% [markdown]
# ####  Using the trimming method to deal with the outliers, by first creating an index for all the data points where the year takes 2017 and 2020  values.
# #### Then the index rows are  dropped from the data, while displaying the  summary of the statistics for the variables.

# %%
# Indexing the data points
index = vgs_1[(vgs_1['Year'] > 2016)].index

# Dropping from the data
vgs_drop =vgs_1.drop(index, inplace=True)

# %%
# Displaying the summary.
vgs_1['Year'].describe()
# Out:
# count    16594.000000
# mean      2006.400145
# std          5.802787
# min       1980.000000
# 25%       2003.000000
# 50%       2007.000000
# 75%       2010.000000
# max       2016.000000
# Name: Year, dtype: float64

# %% [markdown]
# ### Checking for the relationship between the variables

# %%
# using the correlation matrix and heatmap
# calculate correlation matrix
corr_matrix = vgs_1.corr()
# plot the heatmap
sns.heatmap(corr_matrix, xticklabels=corr_matrix.columns,yticklabels=corr_matrix.columns, annot=True, cmap="Spectral")
sns.set(rc={'figure.figsize':(8, 9)})
plt.title("A Heatmap showing the correlation between variables", fontdict = {'fontsize' : 16})
# Out:
# Text(0.5, 1, 'A Heatmap showing the correlation between variables')

# %% [markdown]
# #### Observations:
# It is clear from the heatmap and the sns correlation graphs that:
# * There is a very high positive correlation(0.94) between global sales and north american sales. This is closely followed by the correlation between global sales and EU_sales(0.9). This shows that global sales tend to increase more with North American and European sales
#
# * There is an almost zero correlation between years and global sales, North American sales, and all the other sales values. This shows that there is no clear linear relationship between years and sales. Hence as years increase, sales do not move in any clear direction.

# %%
# pair plot to further visualize the relationship between the variables
sns.pairplot(vgs_1);

# %% [markdown]
# These pair plots further visualize the relationship between the variables and confirms the observations from the heat map

# %% [markdown]
# # Questions

# %% [markdown]
# ### 1. What is the trend of global video game sales over the years?

# %%
# to get the trend of global sales over the years, we need to find the total sales per year.
sale_by_year= vgs_1[['Year','Global_Sales']]
sale_by_year = sale_by_year.groupby('Year')['Global_Sales'].sum().sort_values(ascending=False)
sale_by_year = pd.DataFrame(sale_by_year).reset_index()

# taking a sample to see if sum was done
sale_by_year.sample(5)
# Out:
#     Year  Global_Sales
# 28  1988         47.22
# 11  2003        363.27
# 16  1999        253.53
# 0   2008        684.72
# 10  2012        367.55

# %%
# plotting the total sales per year to see the trend in sales over the years.
sns.lmplot(x='Year', y='Global_Sales', data=sale_by_year, palette = 'Set6', markers =['x'])

# %% [markdown]
# ##### Insight:
# * From the plot above, it is clear that there is no linear trend in the distribution of global sales for the video games over the years. The global video games sales rises slowly in the initial years(1980 to mid 1990s). From the mid 1990s, it sharply increases and reaches an apex in 2008. From there, there is a sharp decline over the years.

# %% [markdown]
# ### 2. Years that had the highest and lowest game sales.

# %%
# top five global video game sales by year
top_five = sale_by_year.head()
top_five
# Out:
#    Year  Global_Sales
# 0  2008        684.72
# 1  2009        678.12
# 2  2007        621.32
# 3  2010        612.11
# 4  2006        536.84

# %% [markdown]
# This table shows that the year with the highest video game sales was the year 2008, followed by 2009. All the years in the top 5 were from the last decade. This is an indication that the 2000s were a good time for the video game industry in terms of sales.

# %%
# visualizing the top five global game sales by year
plt.figure(figsize=(10, 6))
sns.barplot(x='Year', y='Global_Sales', data = top_five)
plt.title("Top five global game sales by year", fontdict = {'fontsize' : 16})
# Out:
# Text(0.5, 1.0, 'Top five global game sales by year')

# %% [markdown]
# This histogram further visualizes the top 5 years by video game sales.

# %%
# bottom five global video game sales by year
bottom_five = sale_by_year.tail()
bottom_five
# Out:
#     Year  Global_Sales
# 32  1991         32.23
# 33  1982         28.86
# 34  1987         21.74
# 35  1983         16.79
# 36  1980         11.38

# %%
# visualizing the bottom five global game sales by year
plt.figure(figsize=(10, 6))
sns.barplot(x='Year', y='Global_Sales', data = bottom_five)
plt.title("Bottom five global game sales by year", fontdict = {'fontsize' : 16})
# Out:
# Text(0.5, 1.0, 'Bottom five global game sales by year')

# %% [markdown]
# The bottom 5 years in terms of the video game sales were in the 1980s and 1990s. This is a confirmation of the fact that the video game market was now experiencing growth and popularity in those years. It could also be due to the fact that there was limited access to computers and machines in that time period.

# %% [markdown]
# ### 3. Which regions have the highest share of global video game sales?

# %%
sum_NA_sales = vgs_1['NA_Sales'].sum()
sum_EU_sales = vgs_1['EU_Sales'].sum()
sum_JP_sales = vgs_1['JP_Sales'].sum()
sum_Others_sales = vgs_1['Other_Sales'].sum()
dict = {'North_America':sum_NA_sales, 'Europe':sum_EU_sales, 'Japan':sum_JP_sales, 'Others':sum_Others_sales}
regional_sales = DataFrame(dict.items(), columns=['Region', 'Sum_of_Regional_Sales'])
regional_sales
# Out:
#           Region  Sum_of_Regional_Sales
# 0  North_America                4392.68
# 1         Europe                2434.13
# 2          Japan                1290.97
# 3         Others                 797.73

# %%
# visualizing

fig1, ax1 = plt.subplots()
ax1.pie(regional_sales['Sum_of_Regional_Sales'], 
        explode=[0.1, 0, 0, 0], 
        labels=['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales'], 
        autopct='%5.1f%%',
        shadow=True ,
        pctdistance=0.7,
        radius = 5,
        startangle=270)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# The pie chart above clearly shows that North American Sales have the highest share of global sales. Almost half(49.3%) of video games that have been sold since 1980 were sold in North America. This shows how huge the video game market is in that region. Also, close to a third of the sales occured in Europe, with the rest being shared between Japan and the rest of the world.

# %% [markdown]
# ### 4. What is the trend of Video game sales in North America over the years?

# %%
na_sale_by_year= vgs_1[['Year','NA_Sales']]
na_sale_by_year = na_sale_by_year.groupby('Year')['NA_Sales'].sum().sort_values(ascending=False)
na_sale_by_year = pd.DataFrame(na_sale_by_year).reset_index()
sns.lmplot(x='Year', y='NA_Sales', data=na_sale_by_year, palette = 'Set6', markers =['x'])
plt.title("North American Sales over the years", fontdict={'fontsize':16})
# Out:
# Text(0.5, 1, 'North American Sales over the years')

# %% [markdown]
# From this plot, North American sales exhibit similar behavior to the global sales when compared to the years. North American sales increase slowly in the 1980s through to the middle of the 1990s. From there it increases rapidly, reaches an apex in 2008 and declines sharply afterwards.

# %% [markdown]
# ### 5. Which platforms have the highest  share of global video game sales?

# %%
#Platforms with highest share of global video game sales.
popular_Platform =vgs_1.Platform.value_counts().nlargest(5)
popular_Platform

 
fig1, ax1 = plt.subplots()
ax1.pie(popular_Platform, 
        explode=[0.1, 0, 0, 0, 0], 
        labels=['DS', 'PS 2', 'PS 3', 'Wii', 'X360'], 
        autopct='%5.2f%%',
        shadow=True ,
        pctdistance=0.7,
        radius = 5,
        startangle=270)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# An initial look at the pie chart reveals that DS seem to have the highest share of global game sales(26.23%). However the PlayStation platforms PS 2 and PS 3 have 16.12% and 26.22% of the global game sales shares. When combined, PlayStation has about 42.3% share of global video game sales.This is almost half of the entire sales worldwide. This is therefore a clear indication that PlayStation platforms are very popular among gamers.
